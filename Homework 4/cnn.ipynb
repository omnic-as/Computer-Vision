# %% [markdown]
# # Использование сверточной нейронной сети для задачи классификации
#
# ### Задание:
# - выбрать один из фреймворков PyTorch/Tensorflow и разработать сверточную НС с 10-15 слоями, с использованием методов, предоставленных фреймворками
# - использовать методы аугментации датасета
# - поэкспериментировать с гиперпараметрами для достижения высшей точности
# - кратко (в нескольких пунктах/предложениях) описать ваши наблюдения, какая архитектура сети и параметры оказались наилучшими

# %% [markdown]
# Датасет CIFAR10 можете взять из предыдущего домашнего задания или использовать доступный датасет во фреймворках. Например,
# - в Pytorch - см. [CIFAR dataset](https://pytorch.org/vision/stable/datasets.html#cifar):
# ```
#     from torchvision.datasets import CIFAR10
#
#     train_transformations = ...
#     train_set =CIFAR10(root="./data", train=True, transform=train_transformations, download=True)
#
#     test_transformations = ...
#     test_set = CIFAR10(root="./data", train=False, transform=test_transformations, download=True)
# ```
#
# - в Tensorflow - см. [CIFAR10](https://www.tensorflow.org/datasets/catalog/cifar10), [load_data](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/cifar10/load_data):
# ```
#     from tensorflow.keras.datasets import cifar10
#
#     (X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# ```
